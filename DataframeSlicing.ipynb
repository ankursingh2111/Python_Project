# %%
import pandas
df1=pandas.read_json("http://pythonhow.com/supermarkets.json")
df1
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df1.loc(1:3)
# Out:
#   File "<ipython-input-5-48845b42789a>", line 1
#     df1.loc(1:3)
#              ^
# SyntaxError: invalid syntax

# %%
df1.columns
# Out:
# Index(['Address', 'City', 'Country', 'Employees', 'ID', 'Name', 'State'], dtype='object')

# %%
df1.index
# Out:
# Int64Index([0, 1, 2, 3, 4, 5], dtype='int64')

# %%
df1.loc[:,"Country"]
# Out:
# 0    USA
# 1    USA
# 2    USA
# 3    USA
# 4    USA
# 5    USA
# Name: Country, dtype: object

# %%
df1.loc[1:3,"City":"Name"]
# Out:
#             City Country  Employees  ID         Name
# 1  San Francisco     USA         15   2  Bready Shop
# 2  San Francisco     USA         25   3  Super River
# 3  San Francisco     USA         10   4   Ben's Shop

# %%
df1.loc[:,"Country"]
# Out:
# 0    USA
# 1    USA
# 2    USA
# 3    USA
# 4    USA
# 5    USA
# Name: Country, dtype: object

# %%
df1.loc[:]
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df1.iloc[1:3]
# Out:
#           Address           City Country  Employees  ID         Name  \
# 1  735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2     332 Hill St  San Francisco     USA         25   3  Super River
#
#               State
# 1          CA 94119
# 2  California 94114

# %%
df1.iloc[1:3,2:4]
# Out:
#   Country  Employees
# 1     USA         15
# 2     USA         25

# %%
df1.columns[1:3]
# Out:
# Index(['City', 'Country'], dtype='object')

# %%
df1.index[3:7]
# Out:
# Int64Index([3, 4, 5], dtype='int64')

# %%
df1.drop("Country",1)
# Out:
#            Address           City  Employees  ID         Name  \
# 0     3666 21st St  San Francisco          8   1      Madeira
# 1   735 Dolores St  San Francisco         15   2  Bready Shop
# 2      332 Hill St  San Francisco         25   3  Super River
# 3     3995 23rd St  San Francisco         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco         12   5      Sanchez
# 5  551 Alvarado St  San Francisco         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df1.drop(3,0)
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 4        California
# 5          CA 94114

# %%
df1
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df1=df1.drop("Country",1)
df1
# Out:
#            Address           City  Employees  ID         Name  \
# 0     3666 21st St  San Francisco          8   1      Madeira
# 1   735 Dolores St  San Francisco         15   2  Bready Shop
# 2      332 Hill St  San Francisco         25   3  Super River
# 3     3995 23rd St  San Francisco         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco         12   5      Sanchez
# 5  551 Alvarado St  San Francisco         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df1["Country"]=df1.shape[0]*["USA"]
df1
# Out:
#            Address           City  Employees  ID         Name  \
# 0     3666 21st St  San Francisco          8   1      Madeira
# 1   735 Dolores St  San Francisco         15   2  Bready Shop
# 2      332 Hill St  San Francisco         25   3  Super River
# 3     3995 23rd St  San Francisco         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco         12   5      Sanchez
# 5  551 Alvarado St  San Francisco         20   6   Richvalley
#
#               State Couuntry Country
# 0          CA 94114      USA     USA
# 1          CA 94119      USA     USA
# 2  California 94114      USA     USA
# 3          CA 94114      USA     USA
# 4        California      USA     USA
# 5          CA 94114      USA     USA

# %%
df1=df1.drop("Couuntry",1)
df1
# Out:
#            Address           City  Employees  ID         Name  \
# 0     3666 21st St  San Francisco          8   1      Madeira
# 1   735 Dolores St  San Francisco         15   2  Bready Shop
# 2      332 Hill St  San Francisco         25   3  Super River
# 3     3995 23rd St  San Francisco         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco         12   5      Sanchez
# 5  551 Alvarado St  San Francisco         20   6   Richvalley
#
#               State Country
# 0          CA 94114     USA
# 1          CA 94119     USA
# 2  California 94114     USA
# 3          CA 94114     USA
# 4        California     USA
# 5          CA 94114     USA

# %%
df1["Continent"]=df1.shape[0]*["North America"]
df1
# Out:
#            Address           City  Employees  ID         Name  \
# 0     3666 21st St  San Francisco          8   1      Madeira
# 1   735 Dolores St  San Francisco         15   2  Bready Shop
# 2      332 Hill St  San Francisco         25   3  Super River
# 3     3995 23rd St  San Francisco         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco         12   5      Sanchez
# 5  551 Alvarado St  San Francisco         20   6   Richvalley
#
#               State Country      Continent
# 0          CA 94114     USA  North America
# 1          CA 94119     USA  North America
# 2  California 94114     USA  North America
# 3          CA 94114     USA  North America
# 4        California     USA  North America
# 5          CA 94114     USA  North America
